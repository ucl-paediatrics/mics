# %%
# %load_ext autoreload
# %autoreload 2

import seaborn as sns

from mics import simulation

# %%
patients = simulation.generate_patients(100, random_seed=42)
display(patients)

# %%
sns.histplot(
    data=patients.to_pandas(), # Convert polars to pandas, as seaborn works better with pandas DataFrames
    x="age", 
    hue="history_of_stroke", 
    multiple="stack"
)
